# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# * fonte: https://www.kaggle.com/berkerisen/wind-turbine-scada-dataset
#
#
# **A potência de uma turbina eólica está relacionada com alguns parâmetros:**
#
# * velocidade do vento;
# * eficiência do gerador;
# * massa específica do ar;
# * área do rotor.
#
# `VELOCIDADE DO VENTO:` é o principal parâmetro analisado, pois é a partir da sua velocidade que é gerada a energia cinética que esta será convertida em energia elétrica no gerador. Por isso, a angulação do vento entre ele a turbina é um fator pontual, pois a depender a direção que o vento está, ela não irá gerar movimento nas hélices.

# %% [markdown]
# **IMPORTANTO O DATAFRAME E FAZENDO AS VERIFICAÇÕES**

# %%
turbinas_df = pd.read_csv('archive/T1.csv')
turbinas_df.head()
# Out:
#           Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0  01 01 2018 00:00           380.047791          5.311336
# 1  01 01 2018 00:10           453.769196          5.672167
# 2  01 01 2018 00:20           306.376587          5.216037
# 3  01 01 2018 00:30           419.645905          5.659674
# 4  01 01 2018 00:40           380.650696          5.577941
#
#    Theoretical_Power_Curve (KWh)  Wind Direction (°)
# 0                     416.328908          259.994904
# 1                     519.917511          268.641113
# 2                     390.900016          272.564789
# 3                     516.127569          271.258087
# 4                     491.702972          265.674286

# %%
turbinas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50530 entries, 0 to 50529
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date/Time                      50530 non-null  object
#  1   LV ActivePower (kW)            50530 non-null  float64
#  2   Wind Speed (m/s)               50530 non-null  float64
#  3   Theoretical_Power_Curve (KWh)  50530 non-null  float64
#  4   Wind Direction (°)             50530 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 1.9+ MB

# %%
colunas = {
    'Date/Time':'time',
    'LV ActivePower (kW)':'potencia_ativa_kw',
    'Wind Speed (m/s)':'velocidade_vento_ms',
    'Theoretical_Power_Curve (KWh)':'potencia_teorica_kwh',
    'Wind Direction (°)':'direcao_vento'
}

turbinas_df.rename(columns=colunas, inplace=True)

# %%
turbinas_df.time = pd.to_datetime(turbinas_df.time)

# %%
turbinas_df.set_index('time', inplace=True)

# %%
turbinas_df.head()
# Out:
#                      potencia_ativa_kw  velocidade_vento_ms  \
# time
# 2018-01-01 00:00:00         380.047791             5.311336
# 2018-01-01 00:10:00         453.769196             5.672167
# 2018-01-01 00:20:00         306.376587             5.216037
# 2018-01-01 00:30:00         419.645905             5.659674
# 2018-01-01 00:40:00         380.650696             5.577941
#
#                      potencia_teorica_kwh  direcao_vento
# time
# 2018-01-01 00:00:00            416.328908     259.994904
# 2018-01-01 00:10:00            519.917511     268.641113
# 2018-01-01 00:20:00            390.900016     272.564789
# 2018-01-01 00:30:00            516.127569     271.258087
# 2018-01-01 00:40:00            491.702972     265.674286

# %%
plt.figure(figsize=(20,8))
ax = sns.scatterplot(x=turbinas_df.velocidade_vento_ms, y=turbinas_df.potencia_teorica_kwh, data=turbinas_df, s=5)
ax.set_title('Relação entre a velocidade do vento e potência teórica', fontsize=18)
ax.set_xlabel('Velocidade do vento $(m/s)$', fontsize=14)
ax.set_ylabel('Potência teórica $(kwh)$', fontsize=14)
plt.grid()

# %%
plt.figure(figsize=(20,8))
ax = sns.scatterplot(x=turbinas_df.velocidade_vento_ms, y=turbinas_df.potencia_ativa_kw,
                     data=turbinas_df)

ax.set_title('Relação entre a velocidade do vento e a potência ativa', fontsize=18)
ax.set_xlabel('Velocidade do vento $(m/s)$', fontsize=14)
ax.set_ylabel('Potencia ativa $(kw)$', fontsize=14)

plt.grid()

# %% [markdown]
# **TEÓRICO**
#
# A relação entre a `velocidade do vento` e a `potência teórica` é positiva, isto é, o aumento da velocidade causa o aumento da potência. Além disso, observar-se que a potência tem um limite máximo, isto é, a partir da velocidade de 11 m/s, a potência produzida alcança o seu valor máximo e existe uma velocidade mínima para começar a produzir potência.
#
# <hr>
#
# **REAL**
#
# A relação entre a `velocidade do vento` e a `potência ativa` é positiva, isto é, o aumento da velocidade causa o aumento da potência. Além disso, observar-se que a potência tem um limite máximo, isto é, a partir da velocidade de 11 m/s, a potência produzida alcança o seu valor máximo e existe uma velocidade mínima para começar a produzir potência. Cabe salientar que, existem muitas medições zeradas, pois no momento da aferição não foi possível captar a potência produzida, apesar de haver velocidades de vento com energia suficiente para produzir energia.

# %%
plt.figure(figsize=(20,8))

ax = sns.scatterplot(x=turbinas_df.velocidade_vento_ms, y=turbinas_df.potencia_ativa_kw, data=turbinas_df, s=5)
ax.set_title('Relação entre a velocidade do vento e a potência ativa', fontsize=18)
ax.set_xlabel('Velocidade do vento $(m/s)$', fontsize=14)
ax.set_ylabel('Potencia ativa $(kw)$', fontsize=14)


ax = sns.scatterplot(x=turbinas_df.velocidade_vento_ms, y=turbinas_df.potencia_teorica_kwh, data=turbinas_df, s=5)
ax.set_title('Comparação entre as potências com relação a velocidade do vento', fontsize=18)
ax.set_xlabel('Velocidade do vento $(m/s)$', fontsize=14)
ax.set_ylabel('Potencia $(kwh)$', fontsize=14)



plt.legend(labels=['real', 'teórico'], title='Potências', title_fontsize=20, prop={'size': 20}, shadow=True)

# %% [markdown]
# **COMPARAÇÃO ENTRE A POTÊNCIA TEÓRICA E REAL**
#
# De forma geral, encontra-se muita mais potências abaixo dos valores teóricos do que acima.
#
# Pode-se analisar de uma forma bem rúde a potência:
#
# $P = v_{vento}.\eta_{rotor}$
#
# onde:
#
# $\eta_{rotor}$ considera-se como valor constante;
#
# $v_{vento}$ é um valor variável.
#
# Portanto, nos pontos em que a potência supera a teoria pode-se considerar que alguns parâmetro relacionado ao vento influênciou nesse resultado como também uma aferição errônea. Já nos pontos em que o valor real está abaixo do valor teórico, considera-se normal, pois é esperada a perda de energia devido ao rendimento do motor e perdas por atrito.
#
# <hr>

# %%
plt.figure(figsize=(20,8))
ax = sns.scatterplot(x=turbinas_df.velocidade_vento_ms, y=turbinas_df.potencia_ativa_kw,
                     data=turbinas_df, hue=turbinas_df.direcao_vento, s=10)

ax.set_title('Relação entre a velocidade do vento e a potência ativa', fontsize=18)
ax.set_xlabel('Velocidade do vento $(m/s)$', fontsize=14)
ax.set_ylabel('Potencia ativa $(kw)$', fontsize=14)
# Out:
# Text(0, 0.5, 'Potencia ativa $(kw)$')

# %%
turbinas_df['erro_de_potencia'] = round((abs(turbinas_df.potencia_ativa_kw - turbinas_df.potencia_teorica_kwh)/turbinas_df.potencia_teorica_kwh)*100, 2)

# %%
turbinas_df.sample(3)
# Out:
#                      potencia_ativa_kw  velocidade_vento_ms  \
# time
# 2018-04-09 17:50:00         668.378723             6.816916
# 2018-04-26 01:30:00         501.352509             6.149059
# 2018-07-25 10:30:00           0.000000             2.188734
#
#                      potencia_teorica_kwh  direcao_vento  erro_de_potencia
# time
# 2018-04-09 17:50:00            935.656915      74.279030             28.57
# 2018-04-26 01:30:00            675.437880      62.537540             25.77
# 2018-07-25 10:30:00              0.000000     289.672485               NaN

# %%
turbinas_df.erro_de_potencia.describe()
# Out:
# count    43246.0000
# mean            inf
# std             NaN
# min          0.0000
# 25%          4.4025
# 50%         12.3300
# 75%         22.3500
# max             inf
# Name: erro_de_potencia, dtype: float64

# %%
potencia_zero = turbinas_df[turbinas_df.potencia_ativa_kw == 0]
potencia_zero.head(10)
# Out:
#                      potencia_ativa_kw  velocidade_vento_ms  \
# time
# 2018-03-01 15:40:00                0.0             3.743307
# 2018-03-01 16:10:00                0.0             2.142016
# 2018-03-01 16:20:00                0.0             2.501406
# 2018-03-01 16:30:00                0.0             2.668578
# 2018-03-01 16:40:00                0.0             3.034003
# 2018-03-01 16:50:00                0.0             3.197354
# 2018-03-01 17:00:00                0.0             3.907811
# 2018-04-01 12:40:00                0.0             2.888112
# 2018-04-01 12:50:00                0.0             2.386636
# 2018-04-01 13:00:00                0.0             2.476816
#
#                      potencia_teorica_kwh  direcao_vento  erro_de_potencia
# time
# 2018-03-01 15:40:00             83.986265     245.068207             100.0
# 2018-03-01 16:10:00              0.000000     234.762405               NaN
# 2018-03-01 16:20:00              0.000000     223.308807               NaN
# 2018-03-01 16:30:00              0.000000     226.051697               NaN
# 2018-03-01 16:40:00             17.180593     221.086502             100.0
# 2018-03-01 16:50:00             25.431221     232.679596             100.0
# 2018-03-01 17:00:00            110.979604     241.973099             100.0
# 2018-04-01 12:40:00              0.000000       0.000000               NaN
# 2018-04-01 12:50:00              0.000000     139.275101               NaN
# 2018-04-01 13:00:00              0.000000     153.855606               NaN

# %%
potencia_sem_zero = turbinas_df[turbinas_df.potencia_ativa_kw != 0]
potencia_sem_zero.head()
# Out:
#                      potencia_ativa_kw  velocidade_vento_ms  \
# time
# 2018-01-01 00:00:00         380.047791             5.311336
# 2018-01-01 00:10:00         453.769196             5.672167
# 2018-01-01 00:20:00         306.376587             5.216037
# 2018-01-01 00:30:00         419.645905             5.659674
# 2018-01-01 00:40:00         380.650696             5.577941
#
#                      potencia_teorica_kwh  direcao_vento  erro_de_potencia
# time
# 2018-01-01 00:00:00            416.328908     259.994904              8.71
# 2018-01-01 00:10:00            519.917511     268.641113             12.72
# 2018-01-01 00:20:00            390.900016     272.564789             21.62
# 2018-01-01 00:30:00            516.127569     271.258087             18.69
# 2018-01-01 00:40:00            491.702972     265.674286             22.59

# %%
plt.figure(figsize=(20,8))
ax = sns.scatterplot(x='velocidade_vento_ms', y='potencia_ativa_kw',
                     data=potencia_sem_zero)

ax.set_title('Relação entre a velocidade do vento e a potência ativa', fontsize=18)
ax.set_xlabel('Velocidade do vento $(m/s)$', fontsize=14)
ax.set_ylabel('Potencia ativa $(kw)$', fontsize=14)
# Out:
# Text(0, 0.5, 'Potencia ativa $(kw)$')

# %%
turbinas_df.head()
# Out:
#                      potencia_ativa_kw  velocidade_vento_ms  \
# time
# 2018-01-01 00:00:00         380.047791             5.311336
# 2018-01-01 00:10:00         453.769196             5.672167
# 2018-01-01 00:20:00         306.376587             5.216037
# 2018-01-01 00:30:00         419.645905             5.659674
# 2018-01-01 00:40:00         380.650696             5.577941
#
#                      potencia_teorica_kwh  direcao_vento  erro_de_potencia  \
# time
# 2018-01-01 00:00:00            416.328908     259.994904              8.71
# 2018-01-01 00:10:00            519.917511     268.641113             12.72
# 2018-01-01 00:20:00            390.900016     272.564789             21.62
# 2018-01-01 00:30:00            516.127569     271.258087             18.69
# 2018-01-01 00:40:00            491.702972     265.674286             22.59
#
#                                       limite
# time
# 2018-01-01 00:00:00  potencia_fora_do_limite
# 2018-01-01 00:10:00  potencia_fora_do_limite
# 2018-01-01 00:20:00  potencia_fora_do_limite
# 2018-01-01 00:30:00  potencia_fora_do_limite
# 2018-01-01 00:40:00  potencia_fora_do_limite

# %% [markdown]
# **FILTRANDO OS VALORES DAS POTÊNCIAS**

# %%
# transformando as Series em listas
pot_real= turbinas_df.potencia_ativa_kw.tolist()
pot_teorica = turbinas_df.potencia_teorica_kwh.tolist()

# variáveis auxiliares
pot_max=[]
pot_min=[]
dentro_limite = []

# limite
i = 5

for potencia in pot_teorica:
    pot_max.append(potencia*(1 + i/100))
    pot_min.append(potencia*(1 - i/100))

for p, potencia in enumerate(pot_real):
    if potencia>=pot_min[p] and potencia<=pot_max[p]:
        dentro_limite.append('potencia_dentro_do_limite')
    elif potencia==0:
        dentro_limite.append('potencia_igual_0')
    else:
        dentro_limite.append('potencia_fora_do_limite')

turbinas_df['limite'] = dentro_limite

# %%
turbinas_df.sample(5)
# Out:
#                      potencia_ativa_kw  velocidade_vento_ms  \
# time
# 2018-06-20 18:30:00        1600.383057             8.612996
# 2018-05-02 20:40:00        2427.595947             9.960803
# 2018-11-30 22:10:00         230.502106             5.954475
# 2018-06-27 14:40:00         706.147888             6.441089
# 2018-05-20 09:20:00         369.751587             5.329446
#
#                      potencia_teorica_kwh  direcao_vento  erro_de_potencia  \
# time
# 2018-06-20 18:30:00           1898.118140      61.119652             15.69
# 2018-05-02 20:40:00           2767.488607      75.697449             12.28
# 2018-11-30 22:10:00            609.739802      38.130939             62.20
# 2018-06-27 14:40:00            783.139186      51.608791              9.83
# 2018-05-20 09:20:00            421.248615      24.226419             12.22
#
#                                       limite
# time
# 2018-06-20 18:30:00  potencia_fora_do_limite
# 2018-05-02 20:40:00  potencia_fora_do_limite
# 2018-11-30 22:10:00  potencia_fora_do_limite
# 2018-06-27 14:40:00  potencia_fora_do_limite
# 2018-05-20 09:20:00  potencia_fora_do_limite

# %%
plt.figure(figsize=(25, 12))
plt.grid(True)

cores = {
    'potencia_dentro_do_limite':'red',
    'potencia_igual_0':'green',
    'potencia_fora_do_limite':'blue'
}
ax = sns.scatterplot(x=turbinas_df.velocidade_vento_ms, y=turbinas_df.potencia_ativa_kw,
                     data=turbinas_df, hue=turbinas_df.limite, s=1,
                    palette=cores)

ax.set_title('Relação entre a velocidade do vento e as potências', fontsize=24)
ax.set_xlabel('Velocidade do vento $(m/s)$', fontsize=18)
ax.set_ylabel('Potência $(kw)$', fontsize=18)



plt.legend(title='Potências', title_fontsize=20, prop={'size': 20}, shadow=True)

# %%
potencias_limite = turbinas_df[turbinas_df.limite == 'potencia_dentro_do_limite']
potencias_limite.head()
# Out:
#                      potencia_ativa_kw  velocidade_vento_ms  \
# time
# 2018-01-01 02:40:00         742.985291             6.378913
# 2018-01-01 02:50:00         748.229614             6.446653
# 2018-01-01 03:00:00         736.647827             6.415083
# 2018-01-01 03:10:00         787.246216             6.437531
# 2018-01-01 03:20:00         722.864075             6.220024
#
#                      potencia_teorica_kwh  direcao_vento  erro_de_potencia  \
# time
# 2018-01-01 02:40:00            759.434537     266.593292              2.17
# 2018-01-01 02:50:00            785.281010     265.571808              4.72
# 2018-01-01 03:00:00            773.172863     261.158691              4.72
# 2018-01-01 03:10:00            781.771216     257.560211              0.70
# 2018-01-01 03:20:00            700.764700     255.926498              3.15
#
#                                         limite
# time
# 2018-01-01 02:40:00  potencia_dentro_do_limite
# 2018-01-01 02:50:00  potencia_dentro_do_limite
# 2018-01-01 03:00:00  potencia_dentro_do_limite
# 2018-01-01 03:10:00  potencia_dentro_do_limite
# 2018-01-01 03:20:00  potencia_dentro_do_limite

# %%
plt.figure(figsize=(20, 8))
sns.scatterplot(x='velocidade_vento_ms', y='potencia_ativa_kw', data=potencias_limite, s=1, color='red')
plt.grid()

# %%
plt.figure(figsize=(25, 12))
plt.grid(True)

cores = {
    'potencia_dentro_do_limite':'red',
    'potencia_igual_0':'orange',
    'potencia_fora_do_limite':'blue'
}
ax = sns.scatterplot(x=turbinas_df.velocidade_vento_ms, y=turbinas_df.potencia_ativa_kw,
                     data=turbinas_df, hue=turbinas_df.limite, s=1,
                    palette=cores)

ax.set_title('Relação entre a velocidade do vento e a potência ativa', fontsize=24)
ax.set_xlabel('Velocidade do vento $(m/s)$', fontsize=18)
ax.set_ylabel('Potência $(kw)$', fontsize=18)


ax = sns.scatterplot(x=turbinas_df.velocidade_vento_ms, y=turbinas_df.potencia_teorica_kwh, data=turbinas_df,
                     s=5, color='DeepSkyBlue' )


plt.legend(labels=['Fora do limite', 'Dentro do limite', 'Sem potência', 'Teórica'])

# %%
plt.figure(figsize=(20,8))
ax = sns.scatterplot(x=turbinas_df.potencia_ativa_kw, y=turbinas_df.direcao_vento,
                     data=turbinas_df, s=8)

ax.set_title('Relação entre a velocidade do vento e a potência ativa', fontsize=18)
ax.set_xlabel('Potência ativa', fontsize=14)
ax.set_ylabel('Direção do vento', fontsize=14)
# Out:
# Text(0, 0.5, 'Direção do vento')

# %%
plt.figure(figsize=(20,8))
ax = sns.scatterplot(x=turbinas_df.potencia_teorica_kwh, y=turbinas_df.direcao_vento,
                     data=turbinas_df, s=8)

ax.set_title('Relação entre a velocidade do vento e a potência ativa', fontsize=18)
ax.set_xlabel('Potência teórica', fontsize=14)
ax.set_ylabel('Direção do vento', fontsize=14)
# Out:
# Text(0, 0.5, 'Direção do vento')

# %%
dentro_do_limite = turbinas_df.query('limite == "potencia_dentro_do_limite"')
plt.figure(figsize=(20,8))
ax = sns.scatterplot(x=dentro_do_limite.erro_de_potencia, y=dentro_do_limite.direcao_vento,
                     data=dentro_do_limite, s=8)

ax.set_title('Relação entre o erro percentual e a direção do vento', fontsize=18)
ax.set_xlabel('Erro percentual $(\%)$', fontsize=14)
ax.set_ylabel('Direção do vento', fontsize=14)
plt.grid()

# %% [markdown]
# **CONCLUSÃO:** A partir do gráfico acima pode-se perceber que há uma concentração de erros nas angulações de 50º a 200º com os respectivos desvios. Por isso, recomenda-se a verificação da aferições nessas direções.
